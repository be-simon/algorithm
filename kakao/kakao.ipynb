# %%
import requests
import json

baseurl = 'https://huqeyhi95c.execute-api.ap-northeast-2.amazonaws.com/prod'
token = '44c304af0bd0dcdf5c96a88655efb937'

req = requests.post(baseurl + '/start',headers={'X-Auth-Token':token} , params={'problem':2})
authkey = req.json()['auth_key']

headers={'Authorization':authkey}

# %%
print('>>> start -----------------')
print(authkey)

def getWaiting():
    req = requests.get(baseurl+'/waiting_line', headers=headers)
    return req.json()['waiting_line']

def getGameResult():
    req = requests.get(baseurl + '/game_result', headers=headers)
    return req.json()['game_result']

def getUserInfo():
    req = requests.get(baseurl+'/user_info', headers=headers)
    return req.json()['user_info']

def match(data_list):
    data = {"pairs": data_list}
    req = requests.put(baseurl + '/match', headers=headers, data=json.dumps(data))
    return req.json()

def changeGrade(commands):
    data = {"commands": commands}
    req = requests.put(baseurl + '/change_grade', headers=headers, data=json.dumps(data))

###


def orderByGrade(uinfo):
#     print('>>> order by grade')
    wlist = getWaiting()
    user_to_grade = dict()
        
    for u in wlist:
        uid = u['id']
        turn = u['from']
        ugrade = uinfo[uid-1]['grade']
        user_to_grade[uid] = (ugrade, turn)

    return sorted(user_to_grade.items(), key=lambda x: x[1])


def getMatchList(order_by_grade):
#     print('>>> get match list')
    match_list = []
    while order_by_grade:
        if len(order_by_grade) >= 2:
            u1, gt1 = order_by_grade.pop()
            ug1 = gt1[0]
            u2, gt2 = order_by_grade.pop()
            ug2 = gt2[0]
            
            if abs(ug1 - ug2) < 250:
                match_list.append([u1, u2])
            else:
                order_by_grade.append((u2, gt2))
        else:
            break

    return match_list


def simulateGame(uinfo):
    ordered = orderByGrade(uinfo)
    ml = getMatchList(ordered)

    res = match(ml)
    print(res)
    return res

def change(results, uinfo):
    commands = []
    for result in results:
        win = result['win']
        lose = result['lose']
        taken = result['taken']
        
        wg = uinfo[win-1]['grade']
        lg = uinfo[lose-1]['grade']

        delta = 1 / (1 + pow(10, abs(wg - lg) / 400))
        k = 500
        
        if taken > 10:
            commands.append({"id": win, "grade": wg + int(k * (1-delta))})
            commands.append({"id": lose, "grade": lg + int(k * (0-delta))})
    
    changeGrade(commands)


    
init_commands = [{"id": i, "grade": 5000} for i in range(1, 901)]
changeGrade(init_commands)
# Out:
# >>> start -----------------
# 7f354b4b-2be5-4652-ab1d-7f51b7288b1f

# %%
status = 1
i = 0
while status:
    if i % 3 == 0:
        uinfo = getUserInfo()
        res = simulateGame(uinfo)
        if res['status'] == 'ready':
            status = 1
        else:
            status = 0
    else:
        match([])
        
    result = getGameResult()
    if result:
        change(result, uinfo)
    
    i += 1


req = requests.get(baseurl + '/score', headers=headers)
print(req.json())
# Out:
# {'status': 'ready', 'time': 1}
# {'status': 'ready', 'time': 4}
# {'status': 'ready', 'time': 7}
# {'status': 'ready', 'time': 10}
# {'status': 'ready', 'time': 13}
# {'status': 'ready', 'time': 16}
# {'status': 'ready', 'time': 19}
# {'status': 'ready', 'time': 22}
# {'status': 'ready', 'time': 25}
# {'status': 'ready', 'time': 28}
# {'status': 'ready', 'time': 31}
# {'status': 'ready', 'time': 34}
# {'status': 'ready', 'time': 37}
# {'status': 'ready', 'time': 40}
# {'status': 'ready', 'time': 43}
# {'status': 'ready', 'time': 46}
# {'status': 'ready', 'time': 49}
# {'status': 'ready', 'time': 52}
# {'status': 'ready', 'time': 55}
# {'status': 'ready', 'time': 58}
# {'status': 'ready', 'time': 61}
# {'status': 'ready', 'time': 64}
# {'status': 'ready', 'time': 67}
# {'status': 'ready', 'time': 70}
# {'status': 'ready', 'time': 73}
# {'status': 'ready', 'time': 76}
# {'status': 'ready', 'time': 79}
# {'status': 'ready', 'time': 82}
# {'status': 'ready', 'time': 85}
# {'status': 'ready', 'time': 88}
# {'status': 'ready', 'time': 91}
# {'status': 'ready', 'time': 94}
# {'status': 'ready', 'time': 97}
# {'status': 'ready', 'time': 100}
# {'status': 'ready', 'time': 103}
# {'status': 'ready', 'time': 106}
# {'status': 'ready', 'time': 109}
# {'status': 'ready', 'time': 112}
# {'status': 'ready', 'time': 115}
# {'status': 'ready', 'time': 118}
# {'status': 'ready', 'time': 121}
# {'status': 'ready', 'time': 124}
# {'status': 'ready', 'time': 127}
# {'status': 'ready', 'time': 130}
# {'status': 'ready', 'time': 133}
# {'status': 'ready', 'time': 136}
# {'status': 'ready', 'time': 139}
# {'status': 'ready', 'time': 142}
# {'status': 'ready', 'time': 145}
# {'status': 'ready', 'time': 148}
# {'status': 'ready', 'time': 151}
# {'status': 'ready', 'time': 154}
# {'status': 'ready', 'time': 157}
# {'status': 'ready', 'time': 160}
# {'status': 'ready', 'time': 163}
# {'status': 'ready', 'time': 166}
# {'status': 'ready', 'time': 169}
# {'status': 'ready', 'time': 172}
# {'status': 'ready', 'time': 175}
# {'status': 'ready', 'time': 178}
# {'status': 'ready', 'time': 181}
# {'status': 'ready', 'time': 184}
# {'status': 'ready', 'time': 187}
# {'status': 'ready', 'time': 190}
# {'status': 'ready', 'time': 193}
# {'status': 'ready', 'time': 196}
# {'status': 'ready', 'time': 199}
# {'status': 'ready', 'time': 202}
# {'status': 'ready', 'time': 205}
# {'status': 'ready', 'time': 208}
# {'status': 'ready', 'time': 211}
# {'status': 'ready', 'time': 214}
# {'status': 'ready', 'time': 217}
# {'status': 'ready', 'time': 220}
# {'status': 'ready', 'time': 223}
# {'status': 'ready', 'time': 226}
# {'status': 'ready', 'time': 229}
# {'status': 'ready', 'time': 232}
# {'status': 'ready', 'time': 235}
# {'status': 'ready', 'time': 238}
# {'status': 'ready', 'time': 241}
# {'status': 'ready', 'time': 244}
# {'status': 'ready', 'time': 247}
# {'status': 'ready', 'time': 250}
# {'status': 'ready', 'time': 253}
# {'status': 'ready', 'time': 256}
# {'status': 'ready', 'time': 259}
# {'status': 'ready', 'time': 262}
# {'status': 'ready', 'time': 265}
# {'status': 'ready', 'time': 268}
# {'status': 'ready', 'time': 271}
# {'status': 'ready', 'time': 274}
# {'status': 'ready', 'time': 277}
# {'status': 'ready', 'time': 280}
# {'status': 'ready', 'time': 283}
# {'status': 'ready', 'time': 286}
# {'status': 'ready', 'time': 289}
# {'status': 'ready', 'time': 292}
# {'status': 'ready', 'time': 295}
# {'status': 'ready', 'time': 298}
# {'status': 'ready', 'time': 301}
# {'status': 'ready', 'time': 304}
# {'status': 'ready', 'time': 307}
# {'status': 'ready', 'time': 310}
# {'status': 'ready', 'time': 313}
# {'status': 'ready', 'time': 316}
# {'status': 'ready', 'time': 319}
# {'status': 'ready', 'time': 322}
# {'status': 'ready', 'time': 325}
# {'status': 'ready', 'time': 328}
# {'status': 'ready', 'time': 331}
# {'status': 'ready', 'time': 334}
# {'status': 'ready', 'time': 337}
# {'status': 'ready', 'time': 340}
# {'status': 'ready', 'time': 343}
# {'status': 'ready', 'time': 346}
# {'status': 'ready', 'time': 349}
# {'status': 'ready', 'time': 352}
# {'status': 'ready', 'time': 355}
# {'status': 'ready', 'time': 358}
# {'status': 'ready', 'time': 361}
# {'status': 'ready', 'time': 364}
# {'status': 'ready', 'time': 367}
# {'status': 'ready', 'time': 370}
# {'status': 'ready', 'time': 373}
# {'status': 'ready', 'time': 376}
# {'status': 'ready', 'time': 379}
# {'status': 'ready', 'time': 382}
# {'status': 'ready', 'time': 385}
# {'status': 'ready', 'time': 388}
# {'status': 'ready', 'time': 391}
# {'status': 'ready', 'time': 394}
# {'status': 'ready', 'time': 397}
# {'status': 'ready', 'time': 400}
# {'status': 'ready', 'time': 403}
# {'status': 'ready', 'time': 406}
# {'status': 'ready', 'time': 409}
# {'status': 'ready', 'time': 412}
# {'status': 'ready', 'time': 415}
# {'status': 'ready', 'time': 418}
# {'status': 'ready', 'time': 421}
# {'status': 'ready', 'time': 424}
# {'status': 'ready', 'time': 427}
# {'status': 'ready', 'time': 430}
# {'status': 'ready', 'time': 433}
# {'status': 'ready', 'time': 436}
# {'status': 'ready', 'time': 439}
# {'status': 'ready', 'time': 442}
# {'status': 'ready', 'time': 445}
# {'status': 'ready', 'time': 448}
# {'status': 'ready', 'time': 451}
# {'status': 'ready', 'time': 454}
# {'status': 'ready', 'time': 457}
# {'status': 'ready', 'time': 460}
# {'status': 'ready', 'time': 463}
# {'status': 'ready', 'time': 466}
# {'status': 'ready', 'time': 469}
# {'status': 'ready', 'time': 472}
# {'status': 'ready', 'time': 475}
# {'status': 'ready', 'time': 478}
# {'status': 'ready', 'time': 481}
# {'status': 'ready', 'time': 484}
# {'status': 'ready', 'time': 487}
# {'status': 'ready', 'time': 490}
# {'status': 'ready', 'time': 493}
# {'status': 'ready', 'time': 496}
# {'status': 'ready', 'time': 499}
# {'status': 'ready', 'time': 502}
# {'status': 'ready', 'time': 505}
# {'status': 'ready', 'time': 508}
# {'status': 'ready', 'time': 511}
# {'status': 'ready', 'time': 514}
# {'status': 'ready', 'time': 517}
# {'status': 'ready', 'time': 520}
# {'status': 'ready', 'time': 523}
# {'status': 'ready', 'time': 526}
# {'status': 'ready', 'time': 529}
# {'status': 'ready', 'time': 532}
# {'status': 'ready', 'time': 535}
# {'status': 'ready', 'time': 538}
